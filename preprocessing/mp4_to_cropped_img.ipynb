# %%
import os
import cv2
import dlib

def create_folders(crop_folder):
    """크롭 폴더 구조를 생성합니다."""
    os.makedirs(crop_folder, exist_ok=True)

def pad_image(frame):
    """이미지에 패딩을 추가합니다."""
    orig_height, orig_width = frame.shape[:2]
    max_dim = max(orig_height, orig_width)
    top_pad = (max_dim - orig_height) // 2
    bottom_pad = max_dim - orig_height - top_pad
    left_pad = (max_dim - orig_width) // 2
    right_pad = max_dim - orig_width - left_pad

    padded_frame = cv2.copyMakeBorder(frame, top_pad, bottom_pad, left_pad, right_pad, cv2.BORDER_CONSTANT, value=[0, 0, 0])
    return padded_frame


def video_capture_labeling(video_path, class_id, crop_folder):
    try:
        # 비디오 캡처 객체 생성
        cap = cv2.VideoCapture(video_path)

        # 성공적으로 동영상을 열었는지 확인
        if not cap.isOpened():
            raise FileNotFoundError(f"Error: Could not open video file {video_path}")

        # FPS 정보 가져오기
        fps = cap.get(cv2.CAP_PROP_FPS)
        if fps == 0:
            raise ValueError("Error: FPS value is 0. Check the video file.")

        # 동영상의 총 프레임 수 가져오기
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

        # 동영상의 총 길이 (초) 계산
        total_duration = total_frames / fps
        print(f"Total duration: {total_duration} seconds")

        # 캡처 간격 (초)
        interval_sec = 0.1

        # 동영상 길이에 따른 캡처할 프레임 번호 리스트 생성
        frame_numbers = [int(fps * t) for t in [i * interval_sec for i in range(int(total_duration / interval_sec))]]

        print(f"Frame numbers to capture: {frame_numbers}")

        # dlib의 강아지 얼굴 탐지 모델 로드
        detector = dlib.cnn_face_detection_model_v1('dogHeadDetector.dat')

        capture_count = 1

        for frame_number in frame_numbers:
            # 원하는 프레임으로 이동
            cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)

            # 프레임 읽기
            ret, frame = cap.read()

            # 프레임이 성공적으로 읽혔는지 확인
            if ret:
                # 강아지 얼굴 탐지
                gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
                detections = detector(gray, 1)
                
                # 얼굴이 검출된 경우만 저장
                if detections:
                    orig_height, orig_width = frame.shape[:2]

                    for i, d in enumerate(detections):
                        left, top, right, bottom, _ = (d.rect.left(), d.rect.top(), d.rect.right(), d.rect.bottom(), d.confidence)

                        # 좌표가 이미지 범위를 벗어나지 않도록 조정
                        left = max(0, left)
                        top = max(0, top)
                        right = min(orig_width, right)
                        bottom = min(orig_height, bottom)

                        # 박스에 맞게 이미지 크롭
                        cropped_img = frame[top:bottom, left:right]

                        # 크롭된 이미지가 유효한지 확인
                        if cropped_img.size == 0:
                            print(f"Warning: Cropped image is empty. Skipping this detection.")
                            continue

                        # 크롭된 이미지 리사이즈 (224x224)
                        resized_cropped_img = cv2.resize(cropped_img, (224, 224))

                        # 개별 동영상 폴더 생성
                        video_folder_name = os.path.splitext(os.path.basename(video_path))[0]
                        video_crop_folder = os.path.join(crop_folder, video_folder_name)
                        os.makedirs(video_crop_folder, exist_ok=True)

                        # 크롭된 이미지 저장 경로 설정
                        crop_image_name = f'dog{class_id}_{capture_count}.jpg'
                        crop_image_path = os.path.join(video_crop_folder, crop_image_name)

                        # 크롭된 이미지 저장
                        cv2.imwrite(crop_image_path, resized_cropped_img)
                        print(f"Cropped and resized image saved as {crop_image_path}")

                        capture_count += 1

    except FileNotFoundError as e:
        print(e)
    except ValueError as e:
        print(e)
    except RuntimeError as e:
        print(e)
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    finally:
        if 'cap' in locals():
            # 캡처 객체 해제
            cap.release()

def extract_class_id_from_filename(filename):
    """확장자를 제거하고 파일명에서 숫자를 추출합니다."""
    basename = os.path.splitext(filename)[0]
    numbers = ''.join(filter(str.isdigit, basename))
    return int(numbers) if numbers else 0

def process_all_videos_in_folder(folder_path, crop_folder):
    """폴더 내 모든 비디오 파일을 처리합니다."""
    create_folders(crop_folder)
    
    files = os.listdir(folder_path)
    video_files = [f for f in files if f.endswith('.mp4')]
    
    for video_file in video_files:
        video_path = os.path.join(folder_path, video_file)
        class_id = extract_class_id_from_filename(video_file)
        print(f"Processing {video_path} with class ID {class_id}...")
        video_capture_labeling(video_path, class_id, crop_folder)

folder_path = '../sample_video'
crop_folder = '../cropped_images'

process_all_videos_in_folder(folder_path, crop_folder)
# Out:
# Processing ../sample_video\dog0.mp4 with class ID 0...
# Total duration: 18.685333333333332 seconds
# Frame numbers to capture: [0, 2, 4, 7, 9, 11, 14, 16, 19, 21, 23, 26, 28, 31, 33, 35, 38, 40, 43, 45, 47, 50, 52, 55, 57, 59, 62, 64, 67, 69, 71, 74, 76, 79, 81, 83, 86, 88, 91, 93, 95, 98, 100, 103, 105, 107, 110, 112, 115, 117, 119, 122, 124, 127, 129, 131, 134, 136, 139, 141, 143, 146, 148, 151, 153, 155, 158, 160, 163, 165, 167, 170, 172, 175, 177, 179, 182, 184, 187, 189, 191, 194, 196, 199, 201, 203, 206, 208, 210, 213, 215, 218, 220, 222, 225, 227, 230, 232, 234, 237, 239, 242, 244, 246, 249, 251, 254, 256, 258, 261, 263, 266, 268, 270, 273, 275, 278, 280, 282, 285, 287, 290, 292, 294, 297, 299, 302, 304, 306, 309, 311, 314, 316, 318, 321, 323, 326, 328, 330, 333, 335, 338, 340, 342, 345, 347, 350, 352, 354, 357, 359, 362, 364, 366, 369, 371, 374, 376, 378, 381, 383, 386, 388, 390, 393, 395, 398, 400, 402, 405, 407, 409, 412, 414, 417, 419, 421, 424, 426, 429, 431, 433, 436, 438, 441, 443]
# Cropped and resized image saved as ../cropped_images\dog0\dog0_1.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_2.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_3.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_4.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_5.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_6.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_7.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_8.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_9.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_10.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_11.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_12.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_13.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_14.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_15.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_16.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_17.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_18.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_19.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_20.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_21.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_22.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_23.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_24.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_25.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_26.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_27.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_28.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_29.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_30.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_31.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_32.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_33.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_34.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_35.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_36.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_37.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_38.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_39.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_40.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_41.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_42.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_43.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_44.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_45.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_46.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_47.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_48.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_49.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_50.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_51.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_52.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_53.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_54.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_55.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_56.jpg
# Cropped and resized image saved as ../cropped_images\dog0\dog0_57.jpg
# Processing ../sample_video\dog1.mp4 with class ID 1...
# Total duration: 14.5 seconds
# Frame numbers to capture: [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309, 312, 315, 318, 321, 324, 327, 330, 333, 336, 339, 342, 345, 348, 351, 354, 357, 360, 363, 366, 369, 372, 375, 378, 381, 384, 387, 390, 393, 396, 399, 402, 405, 408, 411, 414, 417, 420, 423, 426, 429, 432]
# Cropped and resized image saved as ../cropped_images\dog1\dog1_1.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_2.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_3.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_4.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_5.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_6.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_7.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_8.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_9.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_10.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_11.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_12.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_13.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_14.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_15.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_16.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_17.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_18.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_19.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_20.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_21.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_22.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_23.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_24.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_25.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_26.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_27.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_28.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_29.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_30.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_31.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_32.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_33.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_34.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_35.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_36.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_37.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_38.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_39.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_40.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_41.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_42.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_43.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_44.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_45.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_46.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_47.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_48.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_49.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_50.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_51.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_52.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_53.jpg
# Cropped and resized image saved as ../cropped_images\dog1\dog1_54.jpg
# Processing ../sample_video\dog10.mp4 with class ID 10...
# Total duration: 10.943333333333333 seconds
# Frame numbers to capture: [0, 2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146, 149, 152, 155, 158, 161, 164, 167, 170, 173, 176, 179, 182, 185, 188, 191, 194, 197, 200, 203, 206, 209, 212, 215, 218, 221, 224, 227, 230, 233, 236, 239, 242, 245, 248, 251, 254, 257, 260, 263, 266, 269, 272, 275, 278, 281, 284, 287, 290, 293, 296, 299, 302, 305, 308, 311, 314, 317, 320, 323]
# Cropped and resized image saved as ../cropped_images\dog10\dog10_1.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_2.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_3.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_4.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_5.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_6.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_7.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_8.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_9.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_10.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_11.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_12.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_13.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_14.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_15.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_16.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_17.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_18.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_19.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_20.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_21.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_22.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_23.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_24.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_25.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_26.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_27.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_28.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_29.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_30.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_31.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_32.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_33.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_34.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_35.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_36.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_37.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_38.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_39.jpg
# Cropped and resized image saved as ../cropped_images\dog10\dog10_40.jpg
# Processing ../sample_video\dog11.mp4 with class ID 11...
# Total duration: 16.678333333333335 seconds
# Frame numbers to capture: [0, 2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146, 149, 152, 155, 158, 161, 164, 167, 170, 173, 176, 179, 182, 185, 188, 191, 194, 197, 200, 203, 206, 209, 212, 215, 218, 221, 224, 227, 230, 233, 236, 239, 242, 245, 248, 251, 254, 257, 260, 263, 266, 269, 272, 275, 278, 281, 284, 287, 290, 293, 296, 299, 302, 305, 308, 311, 314, 317, 320, 323, 326, 329, 332, 335, 338, 341, 344, 347, 350, 353, 356, 359, 362, 365, 368, 371, 374, 377, 380, 383, 386, 389, 392, 395, 398, 401, 404, 407, 410, 413, 416, 419, 422, 425, 428, 431, 434, 437, 440, 443, 446, 449, 452, 455, 458, 461, 464, 467, 470, 473, 476, 479, 482, 485, 488, 491, 494]
# Cropped and resized image saved as ../cropped_images\dog11\dog11_1.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_2.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_3.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_4.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_5.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_6.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_7.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_8.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_9.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_10.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_11.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_12.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_13.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_14.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_15.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_16.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_17.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_18.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_19.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_20.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_21.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_22.jpg
# Cropped and resized image saved as ../cropped_images\dog11\dog11_23.jpg
# Processing ../sample_video\dog2.mp4 with class ID 2...
# Total duration: 5.964291666666666 seconds
# Frame numbers to capture: [0, 2, 4, 7, 9, 11, 14, 16, 19, 21, 23, 26, 28, 31, 33, 35, 38, 40, 43, 45, 47, 50, 52, 55, 57, 59, 62, 64, 67, 69, 71, 74, 76, 79, 81, 83, 86, 88, 91, 93, 95, 98, 100, 103, 105, 107, 110, 112, 115, 117, 119, 122, 124, 127, 129, 131, 134, 136, 139]
# Cropped and resized image saved as ../cropped_images\dog2\dog2_1.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_2.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_3.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_4.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_5.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_6.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_7.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_8.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_9.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_10.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_11.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_12.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_13.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_14.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_15.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_16.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_17.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_18.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_19.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_20.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_21.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_22.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_23.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_24.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_25.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_26.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_27.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_28.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_29.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_30.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_31.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_32.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_33.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_34.jpg
# Cropped and resized image saved as ../cropped_images\dog2\dog2_35.jpg
# Processing ../sample_video\dog3.mp4 with class ID 3...
# Total duration: 12.078733333333334 seconds
# Frame numbers to capture: [0, 2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146, 149, 152, 155, 158, 161, 164, 167, 170, 173, 176, 179, 182, 185, 188, 191, 194, 197, 200, 203, 206, 209, 212, 215, 218, 221, 224, 227, 230, 233, 236, 239, 242, 245, 248, 251, 254, 257, 260, 263, 266, 269, 272, 275, 278, 281, 284, 287, 290, 293, 296, 299, 302, 305, 308, 311, 314, 317, 320, 323, 326, 329, 332, 335, 338, 341, 344, 347, 350, 353, 356]
# Cropped and resized image saved as ../cropped_images\dog3\dog3_1.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_2.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_3.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_4.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_5.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_6.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_7.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_8.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_9.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_10.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_11.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_12.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_13.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_14.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_15.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_16.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_17.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_18.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_19.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_20.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_21.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_22.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_23.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_24.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_25.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_26.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_27.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_28.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_29.jpg
# Cropped and resized image saved as ../cropped_images\dog3\dog3_30.jpg
# Processing ../sample_video\dog4.mp4 with class ID 4...
# Total duration: 10.433333333333334 seconds
# Frame numbers to capture: [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# Cropped and resized image saved as ../cropped_images\dog4\dog4_1.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_2.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_3.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_4.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_5.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_6.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_7.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_8.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_9.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_10.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_11.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_12.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_13.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_14.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_15.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_16.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_17.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_18.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_19.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_20.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_21.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_22.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_23.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_24.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_25.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_26.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_27.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_28.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_29.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_30.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_31.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_32.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_33.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_34.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_35.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_36.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_37.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_38.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_39.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_40.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_41.jpg
# Cropped and resized image saved as ../cropped_images\dog4\dog4_42.jpg
# Processing ../sample_video\dog5.mp4 with class ID 5...
# Total duration: 5.533333333333333 seconds
# Frame numbers to capture: [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162]
# Cropped and resized image saved as ../cropped_images\dog5\dog5_1.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_2.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_3.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_4.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_5.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_6.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_7.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_8.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_9.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_10.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_11.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_12.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_13.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_14.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_15.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_16.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_17.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_18.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_19.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_20.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_21.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_22.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_23.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_24.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_25.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_26.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_27.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_28.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_29.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_30.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_31.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_32.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_33.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_34.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_35.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_36.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_37.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_38.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_39.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_40.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_41.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_42.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_43.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_44.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_45.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_46.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_47.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_48.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_49.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_50.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_51.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_52.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_53.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_54.jpg
# Cropped and resized image saved as ../cropped_images\dog5\dog5_55.jpg
# Processing ../sample_video\dog6.mp4 with class ID 6...
# Total duration: 13.722041666666666 seconds
# Frame numbers to capture: [0, 2, 4, 7, 9, 11, 14, 16, 19, 21, 23, 26, 28, 31, 33, 35, 38, 40, 43, 45, 47, 50, 52, 55, 57, 59, 62, 64, 67, 69, 71, 74, 76, 79, 81, 83, 86, 88, 91, 93, 95, 98, 100, 103, 105, 107, 110, 112, 115, 117, 119, 122, 124, 127, 129, 131, 134, 136, 139, 141, 143, 146, 148, 151, 153, 155, 158, 160, 163, 165, 167, 170, 172, 175, 177, 179, 182, 184, 187, 189, 191, 194, 196, 199, 201, 203, 206, 208, 210, 213, 215, 218, 220, 222, 225, 227, 230, 232, 234, 237, 239, 242, 244, 246, 249, 251, 254, 256, 258, 261, 263, 266, 268, 270, 273, 275, 278, 280, 282, 285, 287, 290, 292, 294, 297, 299, 302, 304, 306, 309, 311, 314, 316, 318, 321, 323, 326]
# Cropped and resized image saved as ../cropped_images\dog6\dog6_1.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_2.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_3.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_4.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_5.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_6.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_7.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_8.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_9.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_10.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_11.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_12.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_13.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_14.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_15.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_16.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_17.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_18.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_19.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_20.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_21.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_22.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_23.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_24.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_25.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_26.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_27.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_28.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_29.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_30.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_31.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_32.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_33.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_34.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_35.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_36.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_37.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_38.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_39.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_40.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_41.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_42.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_43.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_44.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_45.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_46.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_47.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_48.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_49.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_50.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_51.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_52.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_53.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_54.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_55.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_56.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_57.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_58.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_59.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_60.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_61.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_62.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_63.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_64.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_65.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_66.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_67.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_68.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_69.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_70.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_71.jpg
# Cropped and resized image saved as ../cropped_images\dog6\dog6_72.jpg
# Processing ../sample_video\dog7.mp4 with class ID 7...
# Total duration: 12.16 seconds
# Frame numbers to capture: [0, 2, 5, 7, 10, 12, 15, 17, 20, 22, 25, 27, 30, 32, 35, 37, 40, 42, 45, 47, 50, 52, 55, 57, 60, 62, 65, 67, 70, 72, 75, 77, 80, 82, 85, 87, 90, 92, 95, 97, 100, 102, 105, 107, 110, 112, 115, 117, 120, 122, 125, 127, 130, 132, 135, 137, 140, 142, 145, 147, 150, 152, 155, 157, 160, 162, 165, 167, 170, 172, 175, 177, 180, 182, 185, 187, 190, 192, 195, 197, 200, 202, 205, 207, 210, 212, 215, 217, 220, 222, 225, 227, 230, 232, 235, 237, 240, 242, 245, 247, 250, 252, 255, 257, 260, 262, 265, 267, 270, 272, 275, 277, 280, 282, 285, 287, 290, 292, 295, 297, 300]
# Cropped and resized image saved as ../cropped_images\dog7\dog7_1.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_2.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_3.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_4.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_5.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_6.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_7.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_8.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_9.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_10.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_11.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_12.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_13.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_14.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_15.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_16.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_17.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_18.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_19.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_20.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_21.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_22.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_23.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_24.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_25.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_26.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_27.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_28.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_29.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_30.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_31.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_32.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_33.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_34.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_35.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_36.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_37.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_38.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_39.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_40.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_41.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_42.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_43.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_44.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_45.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_46.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_47.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_48.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_49.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_50.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_51.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_52.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_53.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_54.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_55.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_56.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_57.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_58.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_59.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_60.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_61.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_62.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_63.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_64.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_65.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_66.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_67.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_68.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_69.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_70.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_71.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_72.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_73.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_74.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_75.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_76.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_77.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_78.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_79.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_80.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_81.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_82.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_83.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_84.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_85.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_86.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_87.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_88.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_89.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_90.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_91.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_92.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_93.jpg
# Cropped and resized image saved as ../cropped_images\dog7\dog7_94.jpg
